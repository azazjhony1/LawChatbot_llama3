# %%
import os
from dotenv import load_dotenv
load_dotenv()
from groq import Groq

client = Groq(
    api_key=os.getenv("GROQ_API_KEY"),
)

# %%
def generate(question):
    chat_completion = client.chat.completions.create(
    messages=[
        {
          "role": "system",
          "content": """As an expert law agent, your sole task is to draft a comprehensive and legally binding agreement between two parties. The agreement must be detailed, legally sound, and fully compliant with relevant constitutional laws. Focus exclusively on creating the contract and ensure that the final document is complete and professional. Use the headings listed below for reference, incorporating them if they align with the contract requirements; otherwise, adapt or create new headings as necessary. The contract should be exhaustive and cover all necessary legal provisions.
                            Create a contract based on the details provided by the user. Use the headings listed below for reference, incorporating them if they align with the contract requirements; otherwise, adapt or create new headings as necessary.
                            Make sure to not repeat the prompt in the output. only generate the contract.

                            Important Headings:
                            Products, Quantity, Price
                            Pricing
                             Title and Risk of Loss
                            Locations of Supply
                            Affiliates
                            Quality
                            Agreement Period
                            Payment Terms
                            Technical Support
                            Safety, Health & Environment
                            Audit
                            Supply Security
                            Collaboration Planning and Supply Assurance, Forecast
                            Change Control
                            Credit
                            Set-Off and Recovery
                            Economic Conditions and Trends Clause
                            Failure in Performance
                            Change in Circumstances
                            Warranty Dispute Resolution
                            US Law and Regulation
                            Data Privacy
                            Use Acknowledgement
                            Termination
                            Terms and Conditions
                            Governing Law
                            Binding Effect
                            Entire Agreement
                            Order of Precedence"""  
        },
        {
            "role": "user",

            "content": question,
        }
    ],
        model="llama3-8b-8192",
        temperature=0.2,
        max_tokens=4096
    )
    
    return chat_completion.choices[0].message.content

# %%
question = "Can you create a contract between ExxonMobil Chemical Company and West Pharmaceutical Services, Inc. for the sale and purchase of specified products from 2019 to 2023, including details on product quantities, pricing, purchase orders, title and risk of loss, locations of supply, and quality assurance?"
print(generate(question))
# Out:
# CONTRACT FOR THE SALE AND PURCHASE OF SPECIFIED PRODUCTS
#
# This Contract is made and entered into on [DATE] ("Effective Date") by and between:
#
# EXXONMOBIL CHEMICAL COMPANY, a Delaware corporation with its principal place of business at [ADDRESS] ("ExxonMobil"), and
#
# WEST PHARMACEUTICAL SERVICES, INC., a Pennsylvania corporation with its principal place of business at [ADDRESS] ("West Pharmaceutical Services"), collectively referred to as the "Parties".
#
# 1. PRODUCTS, QUANTITY, AND PRICE
#
# ExxonMobil agrees to sell and deliver to West Pharmaceutical Services the following products:
#
# | Product | Quantity | Unit Price |
# | --- | --- | --- |
# | Polyethylene Glycol (PEG) | 10,000 kg | $1.50/kg |
# | Polypropylene (PP) | 5,000 kg | $1.20/kg |
# | Polyvinyl Chloride (PVC) | 8,000 kg | $1.80/kg |
#
# The total price for the products shall be calculated as follows:
#
# * PEG: 10,000 kg x $1.50/kg = $15,000
# * PP: 5,000 kg x $1.20/kg = $6,000
# * PVC: 8,000 kg x $1.80/kg = $14,400
#
# Total Price: $35,400
#
# 2. PRICING
#
# The prices listed above are fixed and non-negotiable. Any changes to the prices shall be agreed upon in writing by both Parties.
#
# 3. TITLE AND RISK OF LOSS
#
# Title to the products shall pass to West Pharmaceutical Services upon delivery. Risk of loss or damage to the products shall pass to West Pharmaceutical Services upon delivery.
#
# 4. LOCATIONS OF SUPPLY
#
# The products shall be delivered to the following locations:
#
# * PEG: [ADDRESS]
# * PP: [ADDRESS]
# * PVC: [ADDRESS]
#
# 5. QUALITY ASSURANCE
#
# ExxonMobil warrants that the products shall meet the following quality standards:
#
# * PEG: Meets or exceeds ASTM D 1364-14
# * PP: Meets or exceeds ASTM D 1600-14
# * PVC: Meets or exceeds ASTM D 1784-14
#
# West Pharmaceutical Services shall inspect the products upon delivery and notify ExxonMobil of any defects or non-conformities within 3 days of delivery.
#
# 6. AGREEMENT PERIOD
#
# This Contract shall be effective from [START DATE] to [END DATE] (the "Agreement Period"). The Agreement Period may be extended or terminated by mutual agreement of the Parties.
#
# 7. PAYMENT TERMS
#
# Payment shall be made within 30 days of delivery. Late payments shall incur a penalty of 1.5% per month or the maximum permitted by law.
#
# 8. TECHNICAL SUPPORT
#
# ExxonMobil shall provide technical support to West Pharmaceutical Services for the duration of the Agreement Period.
#
# 9. SAFETY, HEALTH, AND ENVIRONMENT
#
# Both Parties shall comply with all applicable laws and regulations related to safety, health, and the environment.
#
# 10. AUDIT
#
# Either Party may conduct an audit of the other Party's records and facilities to ensure compliance with this Contract.
#
# 11. SUPPLY SECURITY
#
# ExxonMobil shall maintain the confidentiality of the products and any confidential information related to the products.
#
# 12. COLLABORATION PLANNING AND SUPPLY ASSURANCE, FORECAST
#
# The Parties shall collaborate to ensure a stable and reliable supply of the products.
#
# 13. CHANGE CONTROL
#
# Any changes to this Contract shall be agreed upon in writing by both Parties.
#
# 14. CREDIT
#
# West Pharmaceutical Services shall not assign or transfer its rights or obligations under this Contract without the prior written consent of ExxonMobil.
#
# 15. SET-OFF AND RECOVERY
#
# In the event of non-payment, ExxonMobil may set off any amounts owed to West Pharmaceutical Services against any amounts owed by West Pharmaceutical Services to ExxonMobil.
#
# 16. ECONOMIC CONDITIONS AND TRENDS CLAUSE
#
# In the event of any economic conditions or trends that may affect the supply or demand of the products, the Parties shall negotiate in good faith to adjust the prices or terms of this Contract.
#
# 17. FAILURE IN PERFORMANCE
#
# In the event of a failure in performance by either Party, the non-performing Party shall be given written notice and a reasonable opportunity to cure the failure. If the failure is not cured, the other Party may terminate this Contract.
#
# 18. CHANGE IN CIRCUMSTANCES
#
# In the event of a change in circumstances that may affect the performance of this Contract, the Parties shall negotiate in good faith to adjust the terms of this Contract.
#
# 19. WARRANTY DISPUTE RESOLUTION
#
# Any disputes arising from the quality or performance of the products shall be resolved through arbitration in accordance with the rules of the American Arbitration Association.
#
# 20. US LAW AND REGULATION
#
# This Contract shall be governed by and construed in accordance with the laws of the State of [STATE].
#
# 21. DATA PRIVACY
#
# Both Parties shall comply with all applicable data privacy laws and regulations.
#
# 22. USE ACKNOWLEDGEMENT
#
# By signing below, the Parties acknowledge that they have read, understand, and agree to the terms and conditions of this Contract.
#
# 23. TERMINATION
#
# This Contract may be terminated by either Party upon written notice to the other Party.
#
# 24. TERMS AND CONDITIONS
#
# This Contract constitutes the entire agreement between the Parties and supersedes all prior or contemporaneous agreements or understandings.
#
# 25. GOVERNING LAW
#
# This Contract shall be governed by and construed in accordance with the laws of the State of [STATE].
#
# 26. BINDING EFFECT
#
# This Contract shall be binding upon and inure to the benefit of the Parties and their respective successors, assigns, and affiliates.
#
# 27. ENTIRE AGREEMENT
#
# This Contract constitutes the entire agreement between the Parties and supersedes all prior or contemporaneous agreements or understandings.
#
# 28. ORDER OF PRECEDENCE
#
# In the event of any conflict or inconsistency between the provisions of this Contract, the following order of precedence shall apply:
#
# * The specific provisions of this Contract
# * The general provisions of this Contract
# * The laws of the State of [STATE]
#
# IN WITNESS WHEREOF, the Parties have executed this Contract as of the date first above written.
#
# EXXONMOBIL CHEMICAL COMPANY:
#
# By: ______________________________________
# Title: ______________________________________
# Date: ______________________________________
#
# WEST PHARMACEUTICAL SERVICES, INC.:
#
# By: ______________________________________
# Title: ______________________________________
# Date: ______________________________________
